# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data file
WHO_results_clinical_path = "FluViewPhase2Data/WHO_NREVSS_Clinical_Labs.csv"
WHO_results_public_health_path = "FluViewPhase2Data/WHO_NREVSS_Public_Health_Labs.csv"

# Read the flu data and skip header row
WHO_clinical_df = pd.read_csv(WHO_results_clinical_path, skiprows=1)
WHO_public_df = pd.read_csv(WHO_results_public_health_path, skiprows=1)

WHO_clinical_df.tail()
# Out:
#       REGION TYPE          REGION  YEAR  WEEK TOTAL SPECIMENS TOTAL A TOTAL B  \
# 13171      States       Wisconsin  2020    23             103       0       0
# 13172      States         Wyoming  2020    23               X       X       X
# 13173      States     Puerto Rico  2020    23               0       0       0
# 13174      States  Virgin Islands  2020    23               X       X       X
# 13175      States   New York City  2020    23               X       X       X
#
#       PERCENT POSITIVE PERCENT A PERCENT B
# 13171                0         0         0
# 13172                X         X         X
# 13173                0         0         0
# 13174                X         X         X
# 13175                X         X         X

# %%
WHO_public_df.tail()
# Out:
#     REGION TYPE          REGION SEASON_DESCRIPTION TOTAL SPECIMENS  \
# 265      States       Wisconsin     Season 2019-20            4423
# 266      States         Wyoming     Season 2019-20             239
# 267      States     Puerto Rico     Season 2019-20             757
# 268      States  Virgin Islands     Season 2019-20               X
# 269      States   New York City     Season 2019-20               X
#
#     A (2009 H1N1) A (H3) A (Subtyping not Performed)   B BVic BYam H3N2v
# 265           418     84                         113  22  548   10     0
# 266            53      1                           1   4   25    0     0
# 267           336     52                           0  59   65    6     0
# 268             X      X                           X   X    X    X     X
# 269             X      X                           X   X    X    X     X

# %%
#The results from the public health labs is not by specific weeks and years - 
#can not combine data after 2016 to compare with weekly weather trends
